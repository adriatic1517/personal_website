# %%
import pandas as pd

# %%
pashto = pd.read_json("Pashto_Raverty_full.json")

# %%
pashto.head()
# Out:
#                                                             ا  \
# root                                                   Pashto
# pashto                                                      ا
# phonetic                                                 alif
# normalized                                               alif
# meaning     is the first letter of the Puś̱ẖto, as also of...
#
#                                                            اب  \
# root                                                   Arabic
# pashto                                                     اب
# phonetic                                                  ab,
# normalized                                                ab,
# meaning     s.m. (9th) Father, master, possessor. Sing. an...
#
#                                                            آب  \
# root                                                  Persian
# pashto                                                     آب
# ...

# %%
pashto = pashto.transpose()

# %%
pashto.head(20)
# Out:
#            root  pashto   phonetic normalized  \
# ا        Pashto       ا       alif       alif
# اب       Arabic      اب        ab,        ab,
# آب      Persian      آب        āb,        ab,
# ابا      Arabic     ابا       ibā,       iba,
# ابابکر   Arabic  ابابکر  abā-bakr,  aba-bakr,
# ابابیل   Arabic  ابابیل   abā-bīl,   aba-bil,
# اباحتي   Arabic  اباحتي  abā-ḥatī,  aba-hati,
# اباخیل   Pashto  اباخیل  abā-ḵẖel,  aba-khel,
# آباد    Persian    آباد      ābād,      abad,
# آبادي   Persian   آبادي     ābādī,     abadi,
# ابازي    Pashto   ابازي    abā-zī,    aba-zi,
# اباسین   Pashto  اباسین   abā-sīn,   aba-sin,
# ابتدا    Arabic   ابتدا    ibtidā,    ibtida,
# ابتر     Arabic    ابتر     abtar,     abtar,
# ابتري    Pashto   ابتري    abtarī,    abtari,
# ابد      Arabic     ابد      abad,      abad,
# آبدار   Persian   آبدار     ābdār,     abdar,
# ابدال    Arabic   ابدال     abdāl,     abdal,
# ابدالي   Pashto  ابدالي    abdālī,    abdali,
# ...

# %%
pashto.groupby(['root']).count().drop(columns = ['phonetic', 'normalized', 'meaning'])
# Out:
#           pashto
# root
# Arabic      1898
# Greek          7
# Hebrew         4
# Pashto      6015
# Persian     1169
# Sanskrit     121
# Turkish       32
